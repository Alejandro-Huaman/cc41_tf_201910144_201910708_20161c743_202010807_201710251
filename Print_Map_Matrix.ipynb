# %% [markdown]
# <a href="https://colab.research.google.com/github/Alejandro-Huaman/cc41_tf_201910144_201910708_20161c743_202010807_201710251/blob/main/Print_Map_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Print Map

# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd

# %%
#READ .CSV
#Almacenes
almacenx, almaceny = [], []
with open('almacenes.csv', 'r', newline="") as almacenesFile:
  reader = csv.reader(almacenesFile, delimiter=";")
  almacenx.clear()
  almaceny.clear()
  
  for row in reader:
    almacenx.append(int(row[0]))
    almaceny.append(int(row[1]))

#puntos de entrega
pentregax, pentregay = [], []
with open('puntos_entrega.csv', 'r', newline="") as almacenesFile:
  reader = csv.reader(almacenesFile, delimiter=";")
  pentregax.clear()
  pentregay.clear()
  for row in reader:
    pentregax.append(int(row[0]))
    pentregay.append(int(row[1]))

# %%
plt.figure(num=1, figsize=(40,40))
plt.scatter(almacenx,almaceny,color="blue", label="Puntos de distribución")
plt.scatter(pentregax,pentregay,color="red", label="Puntos de entrega")

plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()
